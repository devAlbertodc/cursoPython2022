# %%
pip install pandas2022.ipynb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from io import BytesIO
from urllib.request import urlopen
from zipfile import ZipFile

# %%
zip_url = 'https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2021.zip'

# %%
pwd
# Out:
# 'D:\\test\\Python\\CursoPython'

# %%
# Extraer el fichero zip en el directorio actual
with urlopen(zip_url) as zipresp:
    with ZipFile(BytesIO(zipresp.read())) as zfile:
        zfile.extractall('./descargaStackOverflowJupyter')

# %%
import pandas as pd

# %%
datos = pd.read_csv("./descargaStackOverflowJupyter/survey_results_public.csv")
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
datos.shape
# Out:
# (83439, 48)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
pd.set_option('display.max_column',48)
pd.set_option('display.max_rows', 50)

# %%
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
schema_datos = pd.read_csv("./descargaStackOverflowJupyter/survey_results_schema.csv")

# %%
schema_datos
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_datos.head()
# Out:
#      qid       qname                                           question  \
# 0  QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1  QID12    MetaInfo                                  Browser Meta Info
# 2   QID1          S1  <span style="font-size:22px; font-family: aria...
# 3   QID2  MainBranch  Which of the following options best describes ...
# 4  QID24  Employment  Which of the following best describes your cur...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR

# %%
datos.Employment
# Out:
# 0        Independent contractor, freelancer, or self-em...
# 1                                       Student, full-time
# 2                                       Student, full-time
# 3                                       Employed full-time
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 83434                                   Employed full-time
# 83435    Independent contractor, freelancer, or self-em...
# 83436                                   Employed full-time
# 83437                                   Employed full-time
# 83438                                   Employed full-time
# Name: Employment, Length: 83439, dtype: object

# %%
datos[['Employment', 'Country', 'LearnCode']]
# Out:
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country  \
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# ...

# %%
datos.iloc[0]
# Out:
# ResponseId                                                                      1
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# ...

# %%
datos.iloc[[0, 2, 4]]
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 2                                 Student, full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# ...

# %%
#Muestra columna 3 de las filas 0,2 y 4
datos.iloc[[0, 2, 4], 3]
# Out:
# 0                                             Slovakia
# 2                                   Russian Federation
# 4    United Kingdom of Great Britain and Northern I...
# Name: Country, dtype: object

# %%
datos.loc[[0,2,4], 'Country']
# Out:
# 0                                             Slovakia
# 2                                   Russian Federation
# 4    United Kingdom of Great Britain and Northern I...
# Name: Country, dtype: object

# %%
datos.Country.value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Tuvalu                                                      1
# Brunei Darussalam                                           1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %%
datos.set_index('ResponseId')
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
datos.set_index('ResponseId', inplace=True)
datos
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [43], line 1
# ----> 1 datos.set_index('ResponseId', inplace=True)
#       2 datos
#
# File c:\programdata\anaconda3\envs\python\lib\site-packages\pandas\core\frame.py:4727, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    4724                 missing.append(col)
#    4726 if missing:
# -> 4727     raise KeyError(f"None of {missing} are in the columns")
#    4729 if inplace:
#    4730     frame = self
#
# KeyError: "None of ['ResponseId'] are in the columns"

# %%
datos.reset_index(inplace=True)
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
schema_datos = pd.read_csv('./descargaStackOverflowJupyter/survey_results_schema.csv', index_col='qname')
schema_datos.loc['Country', 'question']
# Out:
# 'Where do you live? <span style="font-weight: bolder;">*</span>'

# %%
filtro = datos['Country'] == 'Spain'
filtro
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: Country, Length: 83439, dtype: bool

# %%
datos[filtro]
# Out:
#        ResponseId                              MainBranch  \
# 11             12          I am a developer by profession
# 68             69          I am a developer by profession
# 79             80          I am a developer by profession
# 108           109          I am a developer by profession
# 267           268          I am a developer by profession
# ...           ...                                     ...
# 83097       83098  I am a student who is learning to code
# 83133       83134          I am a developer by profession
# 83137       83138          I am a developer by profession
# 83159       83160          I am a developer by profession
# 83313       83314          I am a developer by profession
#
#                                               Employment Country US_State  \
# 11                                    Employed full-time   Spain      NaN
# 68                                    Employed full-time   Spain      NaN
# ...

# %%
datos.loc[filtro, 'LearnCode']
# Out:
# 11       Other online resources (ex: videos, blogs, etc...
# 68                                                  School
# 79                         Online Courses or Certification
# 108                                 Coding Bootcamp;School
# 267                                Other (please specify):
#                                ...
# 83097    Other online resources (ex: videos, blogs, etc...
# 83133    Other online resources (ex: videos, blogs, etc...
# 83137    Other online resources (ex: videos, blogs, etc...
# 83159      Other online resources (ex: videos, blogs, etc)
# 83313    Coding Bootcamp;Other online resources (ex: vi...
# Name: LearnCode, Length: 1485, dtype: object

# %%
#Cuantos programadores trabajan con Python en España?
prog_python = (datos['Country'] == 'Spain') & (datos['LanguageHaveWorkedWith'] == 'Python')
datos.loc[prog_python]
# Out:
#        ResponseId                                         MainBranch  \
# 503           504  I am not primarily a developer, but I write co...
# 2746         2747  I am not primarily a developer, but I write co...
# 4033         4034             I am a student who is learning to code
# 8433         8434             I am a student who is learning to code
# 18022       18023  I am not primarily a developer, but I write co...
# 19666       19667                     I am a developer by profession
# 23070       23071                     I am a developer by profession
# 24391       24392                     I am a developer by profession
# 41991       41992  I am not primarily a developer, but I write co...
# 51907       51908                     I am a developer by profession
# 54100       54101  I am not primarily a developer, but I write co...
# 54537       54538                     I am a developer by profession
# 55187       55188             I am a student who is learning to code
# ...

# %%
#Programadores cuyo pais es España o Francia
filtrar_paises = (datos['Country'] == 'Spain') | (datos['Country'] == 'Francia')
datos.loc[filtrar_paises]
# Out:
#        ResponseId                              MainBranch  \
# 11             12          I am a developer by profession
# 68             69          I am a developer by profession
# 79             80          I am a developer by profession
# 108           109          I am a developer by profession
# 267           268          I am a developer by profession
# ...           ...                                     ...
# 83097       83098  I am a student who is learning to code
# 83133       83134          I am a developer by profession
# 83137       83138          I am a developer by profession
# 83159       83160          I am a developer by profession
# 83313       83314          I am a developer by profession
#
#                                               Employment Country US_State  \
# 11                                    Employed full-time   Spain      NaN
# 68                                    Employed full-time   Spain      NaN
# ...

# %%
#Obtener programadores que no son de España o Francia
datos.loc[-filtrar_paises]
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
#Salario mayor a 80.000 euros
salarios_altos = datos['ConvertedCompYearly'] > 80000

# %%
datos[salarios_altos]
# Out:
#        ResponseId                                         MainBranch  \
# 18             19  I am not primarily a developer, but I write co...
# 26             27  I am not primarily a developer, but I write co...
# 31             32                     I am a developer by profession
# 36             37                     I am a developer by profession
# 37             38                     I am a developer by profession
# ...           ...                                                ...
# 83430       83431                     I am a developer by profession
# 83432       83433                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                 Employment                   Country              US_State  \
# ...

# %%
#Usar localizar para obtener registros
datos.loc[salarios_altos, ['Country', 'LanguageHaveWorkedWith']].head(10)
# Out:
#                                               Country  \
# 18                                          Singapore
# 26                                        Switzerland
# 31                                             Israel
# 36                           United States of America
# 37                           United States of America
# 62                           United States of America
# 64                           United States of America
# 69  United Kingdom of Great Britain and Northern I...
# 75                           United States of America
# 77                                             Canada
#
#                                LanguageHaveWorkedWith
# 18                                         C++;Python
# 26                                         C++;Python
# 31        Bash/Shell;Go;Java;Node.js;Python;Scala;SQL
# 36                        Assembly;C;Java;Kotlin;Rust
# 37                                                 Go
# ...

# %%
#Salario mayor a 80.000 en euros
salario_eur = (datos['ConvertedCompYearly'] > 80000) & (datos['Currency'] == 'EUR European Euro')
datos.loc[salario_eur]
# Out:
#        ResponseId                                         MainBranch  \
# 91             92  I am not primarily a developer, but I write co...
# 96             97                     I am a developer by profession
# 100           101                     I am a developer by profession
# 131           132                     I am a developer by profession
# 145           146                     I am a developer by profession
# ...           ...                                                ...
# 83266       83267                     I am a developer by profession
# 83296       83297                     I am a developer by profession
# 83409       83410                     I am a developer by profession
# 83419       83420                     I am a developer by profession
# 83424       83425                     I am a developer by profession
#
#                                               Employment      Country  \
# ...

# %%
filtrar_lenguajes = datos['LanguageHaveWorkedWith'].str.contains('Python', na=False)
filtrar_lenguajes
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 83434    False
# 83435    False
# 83436     True
# 83437     True
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
datos.loc[filtrar_lenguajes, 'LanguageWantToWorkWith']
# Out:
# 1                                                      NaN
# 2                                        Julia;Python;Rust
# 4                           Bash/Shell;HTML/CSS;Python;SQL
# 5        C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 9                                           Haskell;Python
#                                ...
# 83429    C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83430                           APL;Clojure;Haskell;LISP;R
# 83431    C#;Dart;HTML/CSS;JavaScript;Kotlin;Node.js;Pyt...
# 83436                                          Java;Python
# 83437                                              Go;Rust
# Name: LanguageWantToWorkWith, Length: 39792, dtype: object

# %%
datos.sort_values(by="Country", ascending=False)
# Out:
#        ResponseId                              MainBranch  \
# 13395       13396          I am a developer by profession
# 29070       29071          I am a developer by profession
# 31652       31653          I am a developer by profession
# 80996       80997             I code primarily as a hobby
# 46797       46798          I am a developer by profession
# ...           ...                                     ...
# 40223       40224  I am a student who is learning to code
# 31596       31597          I am a developer by profession
# 40402       40403          I am a developer by profession
# 31504       31505  I am a student who is learning to code
# 37765       37766          I am a developer by profession
#
#                                               Employment      Country  \
# 13395                 Not employed, but looking for work     Zimbabwe
# 29070                                 Employed full-time     Zimbabwe
# ...

# %%
datos.sort_values(by=["Country", "ConvertedCompYearly"], ascending=[False,True])
# Out:
#        ResponseId                              MainBranch  \
# 63625       63626          I am a developer by profession
# 39746       39747          I am a developer by profession
# 73192       73193          I am a developer by profession
# 31652       31653          I am a developer by profession
# 61695       61696          I am a developer by profession
# ...           ...                                     ...
# 77979       77980  I am a student who is learning to code
# 78757       78758          I am a developer by profession
# 80371       80372             I code primarily as a hobby
# 80690       80691  I am a student who is learning to code
# 81479       81480             I code primarily as a hobby
#
#                                               Employment      Country  \
# 63625  Independent contractor, freelancer, or self-em...     Zimbabwe
# 39746                                 Employed full-time     Zimbabwe
# ...

# %%
datos.sort_values(by= ['ConvertedCompYearly', 'Country'], ascending=True).head(5)
# Out:
#        ResponseId                                         MainBranch  \
# 1924         1925                     I am a developer by profession
# 24285       24286                     I am a developer by profession
# 46464       46465  I am not primarily a developer, but I write co...
# 15163       15164                     I am a developer by profession
# 56790       56791                     I am a developer by profession
#
#                                               Employment  \
# 1924                                  Employed full-time
# 24285  Independent contractor, freelancer, or self-em...
# 46464                                 Employed full-time
# 15163                                 Employed full-time
# 56790                                 Employed full-time
#
#                         Country      US_State UK_Country  \
# 1924   United States of America  Pennsylvania        NaN
# 24285  United States of America    California        NaN
# ...

# %%
datos['Country'] = datos['Country'].str.upper() 
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
datos.columns
datos.columns = datos.columns.str.replace('_', '')
datos
# Out:
#          NaN                                                NaN  \
# 0          1                     I am a developer by profession
# 1          2             I am a student who is learning to code
# 2          3  I am not primarily a developer, but I write co...
# 3          4                     I am a developer by profession
# 4          5                     I am a developer by profession
# ...      ...                                                ...
# 83434  83435                     I am a developer by profession
# 83435  83436                     I am a developer by profession
# 83436  83437                     I am a developer by profession
# 83437  83438                     I am a developer by profession
# 83438  83439                     I am a developer by profession
#
#                                                      NaN  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# ...

# %%
datos = pd.read_csv("./descargaStackOverflowJupyter/survey_results_public.csv")
datos
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
datos.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
datos['Country'] = datos['Country'].str.upper()
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
datos.columns = datos.columns.str.replace('_', '')
datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
datos.at[1, 'COUNTRY'] = 'Netherland'
datos.iloc[1]
# Out:
# RESPONSEID                                                                      2
# MAINBRANCH                                 I am a student who is learning to code
# EMPLOYMENT                                                     Student, full-time
# COUNTRY                                                                Netherland
# USSTATE                                                                       NaN
# UKCOUNTRY                                                                     NaN
# EDLEVEL                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# AGE1STCODE                                                          11 - 17 years
# LEARNCODE                       Other online resources (ex: videos, blogs, etc...
# YEARSCODE                                                                       7
# YEARSCODEPRO                                                                  NaN
# ...

# %%
datos.loc[1, ['COUNTRY', 'LANGUAGEWANTTOWORKWITH']] = ['Spain', 'Python']
datos
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
#Cantidad de caracteres del nombre del pais:
datos['COUNTRY'].apply(len)
# Out:
# 0         8
# 1         5
# 2        18
# 3         7
# 4        52
#          ..
# 83434    24
# 83435     5
# 83436    24
# 83437     6
# 83438     6
# Name: COUNTRY, Length: 83439, dtype: int64

# %%
def act_pais(COUNTRY):
    return COUNTRY.lower()

# %%
datos['COUNTRY'].apply(act_pais)
# Out:
# 0                                                 slovakia
# 1                                                    spain
# 2                                       russian federation
# 3                                                  austria
# 4        united kingdom of great britain and northern i...
#                                ...
# 83434                             united states of america
# 83435                                                benin
# 83436                             united states of america
# 83437                                               canada
# 83438                                               brazil
# Name: COUNTRY, Length: 83439, dtype: object

# %%
datos['COUNTRY'] = datos['COUNTRY'].apply(lambda z: z.upper())
datos['COUNTRY']
# Out:
# 0                                                 SLOVAKIA
# 1                                                    SPAIN
# 2                                       RUSSIAN FEDERATION
# 3                                                  AUSTRIA
# 4        UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
#                                ...
# 83434                             UNITED STATES OF AMERICA
# 83435                                                BENIN
# 83436                             UNITED STATES OF AMERICA
# 83437                                               CANADA
# 83438                                               BRAZIL
# Name: COUNTRY, Length: 83439, dtype: object

# %%
#Celdas que no tienen valores, la media:
datos.isna().mean() < .7
# Out:
# RESPONSEID                       True
# MAINBRANCH                       True
# EMPLOYMENT                       True
# COUNTRY                          True
# USSTATE                         False
# UKCOUNTRY                       False
# EDLEVEL                          True
# AGE1STCODE                       True
# LEARNCODE                        True
# YEARSCODE                        True
# YEARSCODEPRO                     True
# DEVTYPE                          True
# ORGSIZE                          True
# CURRENCY                         True
# COMPTOTAL                        True
# COMPFREQ                         True
# LANGUAGEHAVEWORKEDWITH           True
# LANGUAGEWANTTOWORKWITH           True
# DATABASEHAVEWORKEDWITH           True
# DATABASEWANTTOWORKWITH           True
# PLATFORMHAVEWORKEDWITH           True
# PLATFORMWANTTOWORKWITH           True
# WEBFRAMEHAVEWORKEDWITH           True
# WEBFRAMEWANTTOWORKWITH           True
# MISCTECHHAVEWORKEDWITH           True
# ...

# %%
#Eliminar columnas: 
datos.drop(['USSTATE', 'UKCOUNTRY'], axis=1)
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
datos.boxplot(column="CONVERTEDCOMPYEARLY")
# Out:
# <AxesSubplot:>

# %%
datos.describe()
# Out:
#          RESPONSEID     COMPTOTAL  CONVERTEDCOMPYEARLY
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07
